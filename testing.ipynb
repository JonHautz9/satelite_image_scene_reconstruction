# %%
# %matplotlib tk
from height_map import run, select_points

# %%
#Example Garimas list of heights
heights = [100, 150, 200]
points=[]

points=select_points("StatefarmCenterSatellite.png")
while len(points) != len(heights):
    print(f"Selected {len(points)} points, but need {len(heights)}")
    points=select_points("StatefarmCenterSatellite.png")

# %%
print(points)

for index in range(len(heights)):
    points[index][2] = heights[index]

print(points)
# Out:
# [[568, 499, None], [1033, 431, None], [1097, 402, None]]
# [[568, 499, 100], [1033, 431, 150], [1097, 402, 200]]

# %%
run("StatefarmCenterSatellite.png", refs=points)
